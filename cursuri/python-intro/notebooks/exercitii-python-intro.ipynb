# %% [markdown]
# # Exercitii - Introducere in Python
#
# Apasa **Copy to Drive** inainte sa scrii ceva aici, altfel treaba ta dispare cand inchizi tab-ul.
#
# Rezolva-le in ordine. Nu-ti trebuie nimic in plus fata de ce a fost in notebook-ul de curs - daca te blochezi, revino acolo.

# %% [markdown]
# ## 1. Suma cifrelor unui numar
#
# Extrage cifrele unui numar una cate una, cu impartire si rest la 10, si aduna-le.

# %%
def suma_cifre(n):
    pass  # TODO

suma_cifre(12345)  # ar trebui sa dea 15

# %% [markdown]
# ## 2. Suma elementelor unei liste
#
# Parcurge lista element cu element si acumuleaza suma, fara `sum()`.

# %%
def suma(v):
    pass  # TODO

suma([1, 2, 3, 4, 5])  # ar trebui sa dea 15

# %% [markdown]
# ## 3. Maximul dintr-o lista
#
# Retine cel mai mare element vazut pana acum, pe masura ce parcurgi lista. Fara `max()`.

# %%
def maxim(v):
    pass  # TODO

maxim([3, 7, 2, 9, 4])  # ar trebui sa dea 9

# %% [markdown]
# ## 4. Numararea elementelor pare
#
# Parcurgere plus conditie plus contor - un tipar care revine des.

# %%
def numara_pare(v):
    pass  # TODO

numara_pare([1, 2, 3, 4, 5, 6])  # ar trebui sa dea 3

# %% [markdown]
# ## 5. Palindrom
#
# Un string e palindrom daca se citeste la fel din ambele directii. Foloseste slicing (`s[::-1]` inverseaza un string).

# %%
def e_palindrom(s):
    pass  # TODO

print(e_palindrom('capac'))   # True
print(e_palindrom('carte'))   # False

# %% [markdown]
# ## 6. Numararea cuvintelor dintr-un text
#
# Imparte textul in cuvinte cu `.split()`, apoi construieste un dictionar cuvant -> de cate ori apare.

# %%
def numara_cuvinte(text):
    pass  # TODO

numara_cuvinte('ana are mere ana are pere')  # {'ana': 2, 'are': 2, 'mere': 1, 'pere': 1}

# %% [markdown]
# ## 7. Elimina duplicatele, pastrand ordinea
#
# Un `set` elimina duplicatele, dar iti pierde ordinea initiala. Scrie o functie care pastreaza prima aparitie a fiecarui element, in ordinea din lista originala.

# %%
def fara_duplicate(v):
    pass  # TODO

fara_duplicate([3, 1, 3, 2, 1, 4])  # [3, 1, 2, 4]

# %% [markdown]
# ## 8. Cel mai frecvent element
#
# Gaseste elementul care apare de cele mai multe ori intr-o lista. Poti folosi un dictionar de numarare, sau `collections.Counter` din notebook-ul de curs.

# %%
def cel_mai_frecvent(v):
    pass  # TODO

cel_mai_frecvent([1, 2, 2, 3, 2, 1])  # 2

# %% [markdown]
# ## 9. Patratele numerelor pare
#
# Cu list comprehension: construieste lista patratelor numerelor pare din intervalul `range(1, n + 1)`.

# %%
def patrate_pare(n):
    pass  # TODO

patrate_pare(10)  # [4, 16, 36, 64, 100]

# %% [markdown]
# ## 10. Citire sigura de la tastatura
#
# Scrie o functie care cere un numar cu `input()` si il converteste cu `int()`. Daca utilizatorul scrie ceva ce nu e numar, prinde eroarea cu `try`/`except` si cere din nou, in loc sa crape programul.

# %%
def citeste_numar_sigur():
    pass  # TODO

citeste_numar_sigur()

# %% [markdown]
# ## 11. Matrice construita corect
#
# Construieste o matrice n x n plina cu 0, fara sa cazi in capcana `[[0]*n]*n`. Pune 1 pe diagonala principala (`matrice[i][i] = 1`) si verifica ca restul liniilor n-au fost afectate.

# %%
def matrice_identitate(n):
    pass  # TODO

matrice_identitate(3)  # [[1,0,0], [0,1,0], [0,0,1]]

# %% [markdown]
# ## 12. Factorial, recursiv
#
# Scrie `factorial(n)` recursiv, nu cu bucla. Nu uita cazul de baza.

# %%
def factorial(n):
    pass  # TODO

factorial(5)  # ar trebui sa dea 120

# %% [markdown]
# ## 13. Doua numere care insumeaza un target (two pointers)
#
# Lista `v` e deja sortata crescator. Gaseste doua elemente din `v` a caror suma e exact `target`, in O(n) - fara doua bucle imbricate. Foloseste doi indici, unul de la inceput si unul de la sfarsit.

# %%
def doua_numere(v, target):
    pass  # TODO

doua_numere([1, 3, 4, 6, 8, 11], 10)  # (4, 6)

# %% [markdown]
# ## 14. O fabrica de functii (closure)
#
# Scrie `fabrica_putere(exponent)`, care returneaza o functie ce ridica orice numar la `exponent`. Ca `fabrica_inmultitor` din notebook-ul de curs, dar cu ridicare la putere in loc de inmultire.

# %%
def fabrica_putere(exponent):
    pass  # TODO

la_patrat = fabrica_putere(2)
la_cub = fabrica_putere(3)
print(la_patrat(5), la_cub(5))  # 25 125
